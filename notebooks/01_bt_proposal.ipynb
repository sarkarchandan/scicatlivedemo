# %% [markdown]
# # Demo

# %%
import demo

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Register Beamtime Proposal (along with QR Code Management)

# %%
prop_handler = demo.ProposalHandler()
proposal = prop_handler.get_dummy_proposal()
proposal
# Out:
# Auth token fetched from http://backend.localhost/api/v3.
# {'ownerGroup': 'IPS',
#  'accessGroups': ['IPS', 'LAS'],
#  'proposalId': 'smart_morph_proposal1',
#  'type': 'Default Proposal',
#  'pi_email': 'tomas.farago@kit.edu',
#  'pi_firstname': 'Tomas',
#  'pi_lastname': 'Farago',
#  'email': 'chandan.sarkar@kit.edu',
#  'firstname': 'Chandan',
#  'lastname': 'Sarkar',
#  'title': 'SMART-Morph',
#  'abstract': 'Serial Micro-Tomography',
#  'startTime': '2025-11-03T15:08:50.030Z',
#  'endTime': '2025-11-03T15:08:50.030Z',
#  'metadata': {'samples': [{'Specimen_Name': 'Hymenoptera Hamburg',
#     'Specimen_Code': 'QR_CODE_HH'},
#    {'Specimen_Name': 'Lepidoptera Leipzig', 'Specimen_Code': 'QR_CODE_LL'}]}}

# %%
prop_handler.register(proposal=proposal)
# Out:
# Proposal is registered with Id: smart_morph_proposal1

# %% [markdown]
# ## Make Acquisitions

# %%
acq_handler = demo.AcquisitionHandler()
acq_handler.fetch_proposal(proposal_id="smart_morph_proposal1")
# Out:
# Auth token fetched from http://backend.localhost/api/v3.
# Fetched Proposal: {'_id': 'smart_morph_proposal1', 'createdBy': 'admin', 'updatedBy': 'admin', 'ownerGroup': 'IPS', 'accessGroups': ['IPS', 'LAS'], 'isPublished': False, 'proposalId': 'smart_morph_proposal1', 'pi_email': 'tomas.farago@kit.edu', 'pi_firstname': 'Tomas', 'pi_lastname': 'Farago', 'email': 'chandan.sarkar@kit.edu', 'firstname': 'Chandan', 'lastname': 'Sarkar', 'title': 'SMART-Morph', 'abstract': 'Serial Micro-Tomography', 'startTime': '2025-11-03T15:08:50.030Z', 'endTime': '2025-11-03T15:08:50.030Z', 'MeasurementPeriodList': [], 'metadata': {'samples': [{'Specimen_Name': 'Hymenoptera Hamburg', 'Specimen_Code': 'QR_CODE_HH'}, {'Specimen_Name': 'Lepidoptera Leipzig', 'Specimen_Code': 'QR_CODE_LL'}]}, 'parentProposalId': None, 'type': 'Default Proposal', 'instrumentIds': [], 'createdAt': '2025-11-02T21:17:12.305Z', 'updatedAt': '2025-11-02T21:17:12.305Z', '__v': 0, 'id': 'smart_morph_proposal1'}
# ...

# %%
acq_handler.handle_acquisitions()
# Out:
# Handled acquisition for Hymenoptera Hamburg
# Handled acquisition for Lepidoptera Leipzig
